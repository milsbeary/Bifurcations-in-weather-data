# %%
#Script to download data from all cities in CityList.csv
#Run in order by cell top to bottom

#Last modified by M.H.Kent July 23rd, 2023

#Clears all previous information
import readline 
readline.clear_history()

#Importing needed libraries 
import pandas as pd #Import pandas package for dataframes
import os #Import for setting working dirrectory
import requests #Import for downloading data from database

# %%
#Importing and manipulating list of cities for download

os.chdir('C:/Users/miles/Desktop/ILLME Research/Heatwaves Project and MATH 499/Data/') #Set working dirrectory 

cities = pd.DataFrame(pd.read_csv('CityList.csv', error_bad_lines=False)) #Import city list as a dataframe
print(cities) #View city list

#Adding back zeros that excell deleted infront of the USAF and WBAN numbers
for i in range(0, len(cities)-1): #Note that the df starts at element zero 
    
    #Extracting parameters from dataframe
    usaf_unmodified = cities.loc[i , "USAF"] #Extracts the value by row number and collumn name
    #print(usaf_unmodified) #View extracted parameter
    wban_unmodified = cities.loc[i , "WBAN"]
    #print(wban_unmodified)
    
    #Adding a zero infront of short usaf number
    if usaf_unmodified < 100000:
        cities.loc[i , "USAF"] = str(usaf_unmodified).zfill(6) #Appends a zero at the 6th element infront of the usaf number
        #print(str(usaf_unmodified).zfill(5))
    
    #Adding a zero infronto of short wban number 
    if wban_unmodified < 10000: 
        cities.loc[i , "WBAN"] = str(wban_unmodified).zfill(5) #Appends a zero at the 5th element infront of the wban number
        #print(str(wban_unmodified).zfill(5))

with pd.option_context('display.max_rows', None, 
                       'display.max_columns', None):
     print(cities) #View entire dataframe to make sure everyting is correct
# Out:
#        USAF   WBAN                 STATION_NAME COUNTRY STATE/ICAO     LAT  \
# 0    718920  99999                VANCOUVERINTL      CA       CYVR  49.194
# 1    718960  99999                 PRINCEGEORGE      CA       CYXS  53.889
# 2    711230  99999                 EDMONTONINTL      CA       CYEG  53.310
# 3    718770  99999                  CALGARYINTL      CA       CYYC  51.114
# 4    718660  99999    SASKATOONJGDIEFENBAKERINT      CA       CYXE  52.167
# ..      ...    ...                          ...     ...        ...     ...
# 295  920350  99999      PORTMORESBYJACKSONSINTL      PP       AYPY  -9.443
# 296  915200  99999                  HONIARAINTL      BP       AGGH  -9.428
# 297  916830  99999                  NAUSORIINTL      FJ       NFNA -18.043
# 298  912120  41415     GUAMINTERNATIONALAIRPORT      GQ     GUPGUM  13.483
# 299  917650  61705  TAFUNA/PAGOPAGOINTERNATIONA      AQ     ASNSTU -14.331
#
#          LON  ELEV(M)     BEGIN       END          CITY Unnamed: 11
# 0   -123.184      4.3  19550702  20220512     Vancouver         NaN
# 1   -122.679    691.0  19550702  20220512  PrinceGeorge         NaN
# 2   -113.580    723.3  19601114  20220512      Edmonton         NaN
# 3   -114.020   1084.2  19550702  20220512       Calgary         NaN
# 4   -106.700    503.8  19550702  20220512     Saskatoon         NaN
# ..       ...      ...       ...       ...           ...         ...
# 295  147.220     44.5  19970101  20220512   PortMoresby         NaN
# 296  160.055      8.5  19430316  20220512       Honiara         NaN
# 297  178.559      5.2  19730101  20220512          Suva         NaN
# 298  144.800     77.4  19730101  20220513       Hagatna         NaN
# 299 -170.714      3.7  19450801  20220512      PagoPago         NaN
#
# [300 rows x 12 columns]
#        USAF   WBAN                  STATION_NAME COUNTRY STATE/ICAO     LAT  \
# 39   911820  22521   HONOLULUINTERNATIONALAIRPOR      US     HIPHNL  21.324
# 40   761600  99999     GENERALIGNACIOPGARCIAINTL      MX       MMHO  29.096
# 41   763940  99999                  DELNORTEINTL      MX       MMAN  25.866
# 42   767503  99999                  CABOSANLUCAS      MX       MMSL  22.948
# 43   766133  99999     DONMIGUELHIDALGOYCOSTILLA      MX       MMGL  20.522
# 44   766793  99999    LICENCIADOBENITOJUAREZINTL      MX       MMMX  19.436
# 45   766440  99999    LICENCIADOMANUELCRESCENCIO      MX       MMMD  20.937
# 46   787200  99999                 TONCONTININTL      HO       MHTG  14.061
# 47   787920  99999                   TOCUMENINTL      PM       MPTO   9.071
# 48   782240  99999                 JOSEMARTIINTL      CU       MUHA  22.989
# 49   783970  99999              NORMANMANLEYINTL      JM       MKJP  17.936
# 50   780160  13601     NAVALATLANTICMETEROLOGY&O      BD       TXKF  32.367
# 51   810020  10502                    GEORGETOWN      GY       SYCJ   6.499
# 52   804150  99999              SIMONBOLIVARINTL      VE       SVMI  10.603
# 53   802220  99999                  ELDORADOINTL      CO       SKBO   4.702
# 54   801120  99999              JOSEMARIACORDOVA      CO       SKRG   6.165
# 55   842030  99999              SIMONBOLIVARINTL      EC       SEGU  -2.157
# 56   846280  99999               JORGECHAVEZINTL      PE       SPJC -12.022
# 57   852010  99999                    ELALTOINTL      BL       SLLP -16.513
# 58   862180  99999          SILVIOPETTIROSSIINTL      PA       SGAS -25.240
# 59   854420  99999               CERROMORENOINTL      CI       SCFA -23.444
# 60   855740  99999       ARTUROMERINOBENITEZINTL      CI       SCEL -33.393
# 61   857660  99999                        PICHOY      CI       SCVD -39.650
# 62   859340  99999      CARLOSIBANEZDELCAMPOINTL      CI       SCCI -53.003
# 63   878280  99999                  ALMIRANTEZAR      AR       SAVT -43.211
# 64   877500  99999              COMANDANTEESPORA      AR       SAZB -38.725
# 65   875820  99999        AEROPARQUEJORGENEWBERY      AR       SABE -34.559
# 66   873440  99999           AMBROSIOLVTARAVELLA      AR       SACO -31.324
# 67   839710  99999                  SALGADOFILHO      BR       SBPA -29.994
# 68   837460  99999      GALEAOANTONIOCARLOSJOBIM      BR       SBGL -22.809
# 69   833780  99999   PRESIDENTEJUSCELINOKUBITSCH      BR       SBBR -15.863
# 70   833620  99999                MARECHALRONDON      BR       SBCY -15.653
# 71   832480  99999    DEPUTADOLUISEDUARDOMAGALHA      BR       SBSV -12.911
# 72   823980  99999              PINTOMARTINSINTL      BR       SBFZ  -3.776
# 73   821930  99999                 VALDECANSINTL      BR       SBBE  -1.379
# 74   821110  99999              EDUARDOGOMESINTL      BR       SBEG  -3.039
# 75   042500  99999                NUUK(GODTHAAB)      GL        NAN  64.167
# 76   040300  99999                     REYKJAVIK      IC       BIRK  64.130
# 77   010250  99999                        TROMSO      NO       ENTC  69.683
# 78   013840  99999                    GARDERMOEN      NO       ENGM  60.194
# 79   024640  99999                        BROMMA      SW       ESSB  59.354
# 80   028450  99999                     ROVANIEMI      FI       EFRO  66.565
# 81   029740  99999                HELSINKIVANTAA      FI       EFHK  60.317
# 82   267300  99999                   VILNIUSINTL      LH       EYVI  54.634
# 279  966330  99999                     SEPINGGAN      ID       WALL  -1.268
# 280  971800  99999                    HASANUDDIN      ID       WAAA  -5.062
# 281  977240  99999                     PATTIMURA      ID       WAPP  -3.710
# 282  984290  99999               NINOYAQUINOINTL      RP       RPLL  14.509
# 283  986460  99999                MACTANCEBUINTL      RP       RPVM  10.308
# 284  987530  99999           FRANCISCOBANGOYINTL      RP       RPMD   7.126
# 285  946100  99999                     PERTHINTL      AS       YPPH -31.940
# 286  941200  99999                    DARWININTL      AS       YPDN -12.415
# 287  946720  99999                  ADELAIDEINTL      AS       YPAD -34.945
# 288  948640  99999             MELBOURNEESSENDON      AS       YMEN -37.728
# 289  949750  99999                        HOBART      AS       YMHB -42.836
# 290  949260  99999                      CANBERRA      AS       YSCB -35.307
# 291  947670  99999                    SYDNEYINTL      AS       YSSY -33.946
# 292  945780  99999               BRISBANEAIRPORT      AS       YBBN -27.417
# 293  931190  99999                  AUCKLANDINTL      NZ       NZAA -37.008
# 294  938450  99999        INVERCARGILLAIRPORTAWS      NZ        NAN -46.417
# 295  920350  99999       PORTMORESBYJACKSONSINTL      PP       AYPY  -9.443
# 296  915200  99999                   HONIARAINTL      BP       AGGH  -9.428
# 297  916830  99999                   NAUSORIINTL      FJ       NFNA -18.043
# 298  912120  41415      GUAMINTERNATIONALAIRPORT      GQ     GUPGUM  13.483
# 299  917650  61705   TAFUNA/PAGOPAGOINTERNATIONA      AQ     ASNSTU -14.331
#
#          LON  ELEV(M)     BEGIN       END             CITY Unnamed: 11
# 0   -123.184      4.3  19550702  20220512        Vancouver         NaN
# 1   -122.679    691.0  19550702  20220512     PrinceGeorge         NaN
# 2   -113.580    723.3  19601114  20220512         Edmonton         NaN
# 3   -114.020   1084.2  19550702  20220512          Calgary         NaN
# 4   -106.700    503.8  19550702  20220512        Saskatoon         NaN
# 5    -97.240    238.7  19550702  20220512         Winnipeg         NaN
# 6   -114.440    205.7  19420701  20220512      Yellowknife         NaN
# 7    -89.333    199.0  19550702  20220512       ThunderBay         NaN
# 8    -79.383     76.5  19790507  20220512          Toronto         NaN
# 9    -73.733     36.0  19550101  20220512         Montreal         NaN
# 10   -70.996    159.1  19500102  20220512       Chicoutimi         NaN
# 11   -63.509    145.4  19600701  20220512          Halifax         NaN
# 12   -52.752    140.5  19410929  20220512        St.John's         NaN
# 13   -71.010      3.3  19431121  20220514           Boston         NaN
# 14   -73.764      2.7  19730101  20220513          NewYork         NaN
# 15   -77.447     89.5  19730101  20220513       Washington         NaN
# 16   -78.782    120.5  19451101  20220514          Raleigh         NaN
# 17   -84.442    308.3  19730101  20220513          Atlanta         NaN
# 18   -80.317      1.4  19730101  20220513            Miami         NaN
# 19   -90.278     -1.0  19451001  20220513       NewOrleans         NaN
# 20   -97.022    165.7  19730101  20220513           Dallas         NaN
# 21   -86.688    179.0  19510101  20220513        Nashville         NaN
# 22   -81.852    236.8  19730101  20220513        Cleveland         NaN
# 23   -87.755    185.8  19730101  20220513          Chicago         NaN
# 24   -93.231    254.5  19450101  20220513      Minneapolis         NaN
# 25  -100.758    503.2  19360701  20220513         Bismarck         NaN
# 26   -94.731    307.4  19730101  20220513       KansasCity         NaN
# 27  -104.689   1884.2  19420901  20220513        C.Springs         NaN
# 28  -111.989   1178.1  19730101  20220513           Helena         NaN
# 29  -106.615   1618.4  19410701  20220513      Albuquerque         NaN
# 30  -112.004    339.2  19730101  20220513          Phoenix         NaN
# 31  -118.387     29.7  19440101  20220513       LosAngeles         NaN
# 32  -122.366      3.2  19730101  20220513     SanFrancisco         NaN
# 33  -111.965   1288.4  19411101  20220513              SLC         NaN
# 34  -119.768   1342.5  19430105  20220513             Reno         NaN
# 35  -116.241    860.5  19310101  20220513            Boise         NaN
# 36  -122.609      6.7  19360501  20220513         Portland         NaN
# 37  -150.028     38.0  19730101  20220513        Anchorage         NaN
# 38  -165.440      5.4  19400101  20220513             Nome         NaN
# 39  -157.939      1.9  19390601  20220513         Honolulu         NaN
# 40  -111.048    191.1  19490402  20220512       Hermosillo         NaN
# 41  -100.237    449.9  19730101  20220512        Monterrey         NaN
# 42  -109.939    210.0  19940628  20220512     CaboSanLucas         NaN
# 43  -103.311   1528.9  19900501  20220512      Guadalajara         NaN
# 44   -99.072   2229.9  19850719  20220512       MexicoCity         NaN
# 45   -89.658     11.6  19730101  20220512           Merida         NaN
# 46   -87.217   1004.0  19510101  20220512      Tegucigalpa         NaN
# 47   -79.383     41.1  19730101  20220512       PanamaCity         NaN
# 48   -82.409     64.0  19390101  20220512           Havana         NaN
# 49   -76.788      3.0  19411222  20220512         Kingston         NaN
# 50   -64.683      5.5  19411201  20220513          Bermuda         NaN
# 51   -58.254     29.0  19730101  20220512       Georgetown         NaN
# 52   -66.991     71.6  19730101  20220512          Caracas         NaN
# 53   -74.147   2548.4  19410301  20220512           Bogota         NaN
# 54   -75.423   2142.1  19851201  20220512         Medellin         NaN
# 55   -79.884      5.8  19770701  20220512        Guayaquil         NaN
# 56   -77.114     34.4  19601106  20220512             Lima         NaN
# 57   -68.192   4061.5  19360401  20220512            LaPaz         NaN
# 58   -57.519     89.0  19490101  20220512         Asuncion         NaN
# 59   -70.445    138.7  19350101  20220512      Antofagasta         NaN
# 60   -70.786    474.0  19730101  20220512         Santiago         NaN
# 61   -73.086     18.0  19730101  20220512         Valdivia         NaN
# 62   -70.855     42.4  19350101  20220512      PuntaArenas         NaN
# 63   -65.270     43.0  19390202  20220512           Trelew         NaN
# 64   -62.169     75.0  19390410  20220512      BahiaBlanca         NaN
# 65   -58.416      5.5  19730101  20220512      BuenosAires         NaN
# 66   -64.208    488.9  19390201  20220512          Cordoba         NaN
# 67   -51.171      3.4  19730101  20220512      PortoAlegre         NaN
# 68   -43.244      8.5  19310101  20220512              Rio         NaN
# 69   -47.913   1060.4  19610101  20220512         Brasilia         NaN
# 70   -56.117    188.1  19730101  20220512           Cuiaba         NaN
# 71   -38.331     19.5  19430809  20220512         Salvador         NaN
# 72   -38.533     25.0  19360824  20220512        Fortaleza         NaN
# 73   -48.476     16.5  19421001  20220512            Belem         NaN
# 74   -60.050     80.5  19770501  20220512           Manaus         NaN
# 75   -51.750     84.0  19490101  20220512             Nuuk         NaN
# 76   -21.941     14.6  19310101  20220512        Reykjavik         NaN
# 77    18.919      9.4  19730101  20220512           Tromso         NaN
# 78    11.100    207.6  19400511  20220512             Oslo         NaN
# 79    17.942     14.3  19310101  20220512        Stockholm         NaN
# 80    25.830    196.6  19730101  20220512        Rovaniemi         NaN
# 81    24.963     54.6  19520101  20220512         Helsinki         NaN
# 82    25.286    196.9  19340313  20220512          Vilnius         NaN
# 83    12.656      5.2  19290801  20220512       Copenhagen         NaN
# 84    -2.198     65.5  19260602  20220512         Aberdeen         NaN
# 85    -6.216     81.7  19300228  20220512          Belfast         NaN
# 86    -0.461     25.3  19481201  20220512           London         NaN
# 87     4.764     -3.4  19320503  20220512        Amsterdam         NaN
# 88     2.359     88.7  19370601  20220512            Paris         NaN
# 89    -0.716     49.4  19310101  20220512         Bordeaux         NaN
# 90    -3.567    609.6  19310102  20220512           Madrid         NaN
# 91    -9.136    114.0  19310103  20220512           Lisbon         NaN
# 92     8.543    110.9  19260101  20220512        Frankfurt         NaN
# 93     7.497    510.2  19900424  20220512             Bern         NaN
# 94    16.570    182.9  19520101  20220512           Vienna         NaN
# 95    12.352      2.1  19610301  20220512           Venice         NaN
# 96     9.054      4.0  19431101  20220512         Cagliari         NaN
# 97    20.967    110.3  19280102  20220512           Warsaw         NaN
# 98    19.256    150.9  19520101  20220512         Budapest         NaN
# 99    20.309    102.1  19450501  20220512         Belgrade         NaN
# 100   19.721     38.4  19560101  20220512           Tirana         NaN
# 101   25.180     35.1  19321101  20220512        Heraklion         NaN
# 102   23.406    531.0  19310901  20220512            Sofia         NaN
# 103   26.085     95.7  19730101  20220512        Bucharest         NaN
# 104   14.478     91.4  19310104  20220512         Valletta         NaN
# 105   30.263     24.1  19310401  20220512     StPetersburg         NaN
# 106   37.415    189.6  19730101  20220512           Moscow         NaN
# 107   30.451    178.6  19320101  20220512             Kyiv         NaN
# 108   30.676     52.4  19320101  20220512            Odesa         NaN
# 109   39.230    156.7  19320101  20220512         Voronezh         NaN
# 110   44.333    152.7  19590101  20220512           Elista         NaN
# 111   44.346    146.9  19320101  20220512        Volgograd         NaN
# 112   55.457    118.0  19320101  20220512         Orenburg         NaN
# 113   40.717     18.9  19310104  20220512      Arkhangelsk         NaN
# 114   32.751     81.1  19361231  20220512         Murmansk         NaN
# 115   49.279    126.2  19320101  20220512            Kazan         NaN
# 116   60.803    232.9  19320101  20220512    Yekaterinburg         NaN
# 117   73.402     61.0  19320101  20220512           Surgut         NaN
# 118   64.017    172.0  19530216  20220512          Vorkuta         NaN
# 119   73.311     94.8  19320101  20220512             Omsk         NaN
# 120   82.651    111.3  19320101  20220512      Novosibirsk         NaN
# 121   88.250     64.0  19751001  20220512          Norilsk         NaN
# 122  129.771     99.1  19550305  20220512          Yakutsk         NaN
# 123   87.183    308.0  19550701  20220512     Novokuznetsk         NaN
# 124  104.389    510.5  19320101  20220512          Irkutsk         NaN
# 125  113.306    692.5  19320101  20220512            Chita         NaN
# 126  135.188     75.0  19311231  20220512       Khabarovsk         NaN
# 127  150.720    175.0  19451231  20220512          Magadan         NaN
# 128  158.454     39.9  19320101  20220512    Petropavlovsk         NaN
# 129  142.718     18.0  19530216  20220512    Y.-Sakhalinsk         NaN
# 130   71.467    355.1  19320101  20220512           Astana         NaN
# 131   51.092     22.3  19320201  20220512            Aktau         NaN
# 132   65.533    129.0  19320101  20220512        Kyzylorda         NaN
# 133   74.533    760.0  19460103  20220512          Bishkek         NaN
# 134   69.281    431.9  19320101  20220512         Tashkent         NaN
# 135   59.617     77.0  19591101  20220512            Nukus         NaN
# 136   68.825    784.9  19320101  20220512         Dushanbe         NaN
# 137   58.361    210.9  19320101  20220512         Ashgabat         NaN
# 138   50.047      3.0  19590402  20220512             Baku         NaN
# 139   44.767    427.0  19590101  20220512             Tbil         isi
# 140   60.907   1377.7  19570701  20220512          Zahedan         NaN
# 141   59.641    994.6  19440103  20220512          Mashhad         NaN
# 142   54.401     -7.3  19730101  20220512           Gorgan         NaN
# 143   51.313   1207.6  19431101  20220512           Tehran         NaN
# 144   51.862   1545.9  19480901  20220512          Isfahan         NaN
# 145   52.589   1499.6  19570701  20220512           Shiraz         NaN
# 146   44.349    323.4  19370105  20220512           Kirkuk         NaN
# 147   44.233     34.7  19370104  20220512          Baghdad         NaN
# 148   47.969     62.8  19450802  20220512           Kuwait         NaN
# 149   50.634      1.8  19440101  20220512           Manama         NaN
# 150   55.364     10.4  19830101  20220512            Dubai         NaN
# 151   58.284     14.6  19440101  20220512           Muscat         NaN
# 152   42.586      6.1  19830101  20220512            Jizan         NaN
# 153   46.699    624.5  19831222  20220512           Riyadh         NaN
# 154   39.157     14.6  19830101  20220512           Jeddah         NaN
# 155   34.887     41.1  19431101  20220512          TelAviv         NaN
# 156   35.949     47.9  19500711  20220512          Latakia         NaN
# 157   43.332   1670.3  19570701  20220512              Van         NaN
# 158   39.790     31.7  19510101  20220512          Trabzon         NaN
# 159   32.995    952.5  19670101  20220512           Ankara         NaN
# 160   28.821     49.7  19450613  20220512         Istanbul         NaN
# 161   31.406    116.4  19431031  20220512            Cairo         NaN
# 162   32.820    201.8  19370103  20220512            Aswan         NaN
# 163   32.553    385.6  19421031  20220512         Khartoum         NaN
# 164   20.269    132.0  19431031  20220512         Benghazi         NaN
# 165   10.227      6.7  19430608  20220512            Tunis         NaN
# 166    3.215     25.0  19430401  20220512          Algiers         NaN
# 167   -0.621     89.9  19490102  20220512             Oran         NaN
# 168   -4.978    579.1  19441101  20220512              Fes         NaN
# 169   -7.590    199.9  19421121  20220512       Casablanca         NaN
# 170   -8.036    467.9  19430118  20220512        Marrakesh         NaN
# 171  -13.219     63.1  19610601  20220512         Laayoune         NaN
# 172  -17.030      4.9  19490401  20220512       Nouadhibou         NaN
# 173    5.450   1412.0  19801107  20220512      Tamanrasset         NaN
# 174   43.133     13.0  19961201  20220512         Djibouti         NaN
# 175   38.799   2325.6  19570101  20220512       AddisAbaba         NaN
# 176   41.854   1158.8  19570101  20220512         DireDawa         NaN
# 177   36.928   1623.7  19490121  20220512          Nairobi         NaN
# 178   39.594     61.0  19490121  20220512          Mombasa         NaN
# 179   32.444   1152.8  19490121  20220512          Kampala         NaN
# 180   29.319    787.0  19730101  20220512        Bujumbura         NaN
# 181   39.225     16.5  19570101  20220512         Zanzibar         NaN
# 182   33.781   1261.0  19820501  20220512         Lilongwe         NaN
# 183   28.450   1151.8  19730101  20220512           Lusaka         NaN
# 184   31.094   1489.6  19490101  20220512           Harare         NaN
# 185   32.573     44.2  19730101  20220512           Maputo         NaN
# 186   47.479   1279.6  19730101  20220512     Antananarivo         NaN
# 187   43.272     28.3  19811101  20220512           Moroni         NaN
# 188   27.926   1376.8  19900323  20220512     Johannesburg         NaN
# 189   18.602     46.0  19490101  20220512         CapeTown         NaN
# 190   17.471   1719.1  19730101  20220512         Windhoek         NaN
# 191  -14.394     84.7  19420901  20220512  AscensionIsland         NaN
# 192   13.231     74.1  19490103  20220512           Luanda         NaN
# 193   15.445    313.0  19490704  20220512         Kinshasa         NaN
# 194    9.412     11.9  19490401  20220512       Libreville         NaN
# 195    8.709     23.2  19740618  20220512           Malabo         NaN
# 196   11.553    694.3  19490914  20220512          Yaounde         NaN
# 197   18.519    368.2  19490401  20220512           Bangui         NaN
# 198    4.494    343.2  19500203  20220512           Ilorin         NaN
# 199    8.525    476.1  19430501  20220512             Kano         NaN
# 200   15.034    295.0  19490401  20220512        N'Djamena         NaN
# 201    2.184    223.1  19490401  20220512           Niamey         NaN
# 202   -1.512    316.1  19490401  20220512      Ouagadougou         NaN
# 203   -7.950    380.1  19750101  20220512           Bamako         NaN
# 204   -0.167     62.5  19420701  20220512            Accra         NaN
# 205  -13.612     21.9  19490401  20220512          Conakry         NaN
# 206  -17.490     25.9  19430401  20220512            Dakar         NaN
# 207  -22.949     53.9  19480304  20220512        CapeVerde         NaN
# 208   73.099    508.4  19440101  20220512        Islamabad         NaN
# 209   71.419    121.9  19440101  20220512           Multan         NaN
# 210   67.161     30.5  19420506  20220512          Karachi         NaN
# 211   66.938   1600.2  19440101  20220512           Quetta         NaN
# 212   85.359   1338.1  19730521  20220512        Kathmandu         NaN
# 213   77.103    236.8  19750307  20220512            Delhi         NaN
# 214   73.049    218.5  19430731  20220512          Jodhpur         NaN
# 215   72.635     57.6  19440101  20220512        Ahmedabad         NaN
# 216   72.868     11.3  19440101  20220512           Mumbai         NaN
# 217   77.633    888.0  19420901  20220512        Bangalore         NaN
# 218   76.272      2.4  19440101  20220512            Kochi         NaN
# 219   73.529      1.8  19810101  20220512             Male         NaN
# 220   79.886      6.7  19440513  20220512          Colombo         NaN
# 221   80.181     15.8  19440101  20220512          Chennai         NaN
# 222   78.461    531.0  19440101  20220512        Hyderabad         NaN
# 223   83.217      4.6  19540101  20220512    Visakhapatnam         NaN
# 224   77.337    524.0  19440101  20220512           Bhopal         NaN
# 225   85.088     51.8  19440101  20220512            Patna         NaN
# 226   88.447      4.9  19430831  20220512          Kolkata         NaN
# 227   90.398      9.1  19430715  20220512            Dhaka         NaN
# 228   91.586     49.4  19440102  20220512         Guwahati         NaN
# 229   93.897    774.2  19441202  20220512           Imphal         NaN
# 230  116.585     35.4  19451031  20220512          Beijing         NaN
# 231  121.539     32.6  19560820  20220512           Dalian         NaN
# 232  125.681    215.2  19560820  20220512        Changchun         NaN
# 233  123.918    145.4  19560820  20220512          Qiqihar         NaN
# 234  122.533    438.0  19730101  20220512             Mohe         NaN
# 235  111.824   1083.9  19560820  20220512           Hohhot         NaN
# 236  113.841    150.9  19570601  20220512        Zhengzhou         NaN
# 237  120.374     10.1  19560820  20220512          Qingdao         NaN
# 238  121.336      3.0  19560820  20220512         Shanghai         NaN
# 239  115.900     43.6  19560820  20220512         Nanchang         NaN
# 240  118.128     18.0  19560820  20220512           Xiamen         NaN
# 241  113.915      8.5  19481231  20220512         HongKong         NaN
# 242  109.412     28.0  20040713  20220512            Sanya         NaN
# 243  110.039    173.7  19430606  20220512           Guilin         NaN
# 244  102.744   1894.9  19420713  20220512          Kunming         NaN
# 245  106.801   1138.7  19450204  20220512          Guiyang         NaN
# 246  114.208     34.4  19560820  20220512            Wuhan         NaN
# 247  106.642    416.1  19441111  20220512        Chongqing         NaN
# 248  103.947    495.3  19560820  20220512          Chengdu         NaN
# 249  108.752    479.1  19560820  20220512            Xi'An         NaN
# 250  106.217   1112.0  19560820  20220512         Yinchuan         NaN
# 251  101.767   2262.0  19560820  20220512           Xining         NaN
# 252   87.474    647.7  19850209  20220512           Urumqi         NaN
# 253   79.933   1375.0  19560820  20220512            Hotan         NaN
# 254   91.133   3650.0  19560820  20220512            Lhasa         NaN
# 255  121.552      5.5  19461231  20220512           Taipei         NaN
# 256  125.670     35.7  19501024  20220512        Pyongyang         NaN
# 257  126.791     17.7  19450930  20220512            Seoul         NaN
# 258  128.938      1.8  19540719  20220512            Busan         NaN
# 259  126.493     36.0  19730101  20220512             Jeju         NaN
# 260  141.380      7.6  19730101  20220512          Sapporo         NaN
# 261  139.780     10.7  19460911  20220512            Tokyo         NaN
# 262  136.924     15.8  19461031  20220512           Nagoya         NaN
# 263  130.451      9.8  19460906  20220512          Fukuoka         NaN
# 264  106.767   1330.1  19560802  20220512      Ulaanbaatar         NaN
# 265   97.400    147.0  19440713  20220512        Myitkyina         NaN
# 266   96.100     76.0  19470405  20220512         Mandalay         NaN
# 267   96.133     33.2  19490417  20220512           Yangon         NaN
# 268   98.963    315.8  19421231  20220512        ChiangMai         NaN
# 269  100.607      2.7  19421231  20220512          Bangkok         NaN
# 270   98.317     25.0  19560126  20220512           Phuket         NaN
# 271  102.563    171.9  19490101  20220512        Vientiane         NaN
# 272  104.844     12.2  19490102  20220512        PhnomPenh         NaN
# 273  105.807     11.9  19581201  20220512            Hanoi         NaN
# 274  106.652     10.1  19490102  20220512             HCMC         NaN
# 275  101.549     27.4  19490101  20220512      KualaLumpur         NaN
# 276  103.994      6.7  19560103  20220512        Singapore         NaN
# 277   98.672     34.7  19460201  20220512            Medan         NaN
# 278  106.656     10.4  19850402  20220512          Jakarta         NaN
# 279  116.894      3.7  19471101  20220512       Balikpapan         NaN
# 280  119.554     14.3  19470201  20220512         Makassar         NaN
# 281  128.089     10.1  19490101  20220512            Ambon         NaN
# 282  121.020     22.9  19450331  20220512           Manila         NaN
# 283  123.979      9.4  19650731  20220512         CebuCity         NaN
# 284  125.646     29.3  19740601  20220512            Davao         NaN
# 285  115.967     20.4  19471231  20220512            Perth         NaN
# 286  130.877     31.4  19410131  20220512           Darwin         NaN
# 287  138.531      6.1  19550215  20220512         Adelaide         NaN
# 288  144.902     86.0  19471231  20220512        Melbourne         NaN
# 289  147.510      4.0  19580531  20220512           Hobart         NaN
# 290  149.195    574.9  19390228  20220512         Canberra         NaN
# 291  151.177      6.4  19430923  20220512           Sydney         NaN
# 292  153.067      6.0  19441001  20220512         Brisbane         NaN
# 293  174.792      7.0  19651231  20220512         Auckland         NaN
# 294  168.333      2.0  19890516  20220512     Invercargill         NaN
# 295  147.220     44.5  19970101  20220512      PortMoresby         NaN
# 296  160.055      8.5  19430316  20220512          Honiara         NaN
# 297  178.559      5.2  19730101  20220512             Suva         NaN
# 298  144.800     77.4  19730101  20220513          Hagatna         NaN
# 299 -170.714      3.7  19450801  20220512         PagoPago         NaN

# %%
#Extracting and saving csvs from the NOAA website

# Base URL and filename
url_base_hourly = "https://www.ncei.noaa.gov/data/global-hourly/access/" #Hourly data path (icludes 3 hour data)
url_base = "https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/" #Daily data path 

for i in range(0, len(cities)): #Itterates over each city

    print(i) #Gives itteration the loop is on
    
    #Extracting needed parameters from dataframe
    usaf = cities.loc[i , "USAF"]
    print(usaf) 
    wban = cities.loc[i , "WBAN"]
    print(wban)
    startyear = str(cities.loc[i , "BEGIN"])[:4] #Extracts the year from the date string by taking the first four elements
    #print(startyear)
    endyear = str(cities.loc[i , "END"])[:4]  
    #print(endyear)
    
    #Defines and locates filename
    filename_noaa = str(usaf) + str(wban) + ".csv" #Define CSV file name (Should match what is on the server)
    #print(filename_noaa)
    
    #Downloading files to computer
    for yr in range(int(startyear), int(endyear)+1): #Sets the year values as integers becuase they are initally strings
        #print(yr) #View index 
        
        #Set exact path to match where eah file is on the NOAA website 
        url_loop_daily = url_base + str(yr) + "/" + filename_noaa
        #print(url_loop_daily)
        url_loop_hourly = url_base_hourly + str(yr) + "/" + filename_noaa 
        #print(url_loop_hourly)
        
        #Identifies file on website
        csv_current_daily = requests.get(url_loop_daily, allow_redirects = True)
        csv_current_hourly = requests.get(url_loop_hourly, allow_redirects = True)
        
        #Sets the file name of the local imported file
        filename_local_daily =  str(usaf) + str(wban) + "-" + str(yr) + "DAILY.csv" 
        filename_local_hourly = str(usaf) + str(wban) + "-" + str(yr) + "HOURLY.csv"
        
       
        os.chdir('C:/Users/miles/Desktop/ILLME Research/Heatwaves Project and MATH 499/Data/correctdailycities') #Sets path for daily data csv deposit  
        #open(filename_local_daily, "wb").write(csv_current_daily.content) #Write a csv for daily data
        
        os.chdir('C:/Users/miles/Desktop/ILLME Research/Heatwaves Project and MATH 499/Data/correcthourlycities') #Sets path for hourly data csv deposit
        #open(filename_local_hourly, "wb").write(csv_current_hourly.content) #w opens the file for writing and b puts it in bianary mode
    
    #end of nested loop
#end of origional loop
#Set up a count here
# Out:
# 0
# 718920
# 99999
# 1
# 718960
# 99999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-55b10c0ba538> in <module>
#      35         #Identifies file on website
#      36         csv_current_daily = requests.get(url_loop_daily, allow_redirects = True)
# ---> 37         csv_current_hourly = requests.get(url_loop_hourly, allow_redirects = True)
#      38
#      39         #Sets the file name of the local imported file
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     829                 self._content = None
#     830             else:
# --> 831                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     832
#     833         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
